# %% [markdown]
# <a href="https://colab.research.google.com/github/MDGQC/LZ77/blob/master/Exercise_7_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **K Nearest Neighbors Project**
#
# In this project you are given an anonimized data set with items labeled to two classes -1 and 1. This exercise is very similar to the hands on from the lecture

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a79cd3d6-a7f8-473b-9feb-0093655a0817" name="files[]" multiple disabled />
#      <output id="result-a79cd3d6-a7f8-473b-9feb-0093655a0817">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KNN_Project_Data.csv to KNN_Project_Data.csv

# %% [markdown]
# Read the KNN_Project_Data.csv file into a *dataframe*

# %%
KNN = pd.read_csv('KNN_Project_Data.csv')

# %% [markdown]
# Check the head of the dataframe.

# %%
KNN.head()
# Out:
#           XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0  1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1  1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2  1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3  1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4  1018.340526  1313.679056   950.622661  724.742174   843.065903
#
#           HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0  1618.870897  2147.641254  330.727893  1494.878631   845.136088
# 1  2084.107872   853.404981  447.157619  1193.032521   861.081809
# 2  2552.355407   818.676686  845.491492  1968.367513  1647.186291
# 3   685.666983   852.867810  341.664784  1154.391368  1450.935357
# 4  1370.554164   905.469453  658.118202   539.459350  1899.850792
#
#    TARGET CLASS
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %% [markdown]
# Since this data is artificial, we’ll just do a large pairplot with seaborn.
#
# Use seaborn on the dataframe to create a pairplot with the hue indicated by the TARGET CLASS column.

# %%
sns.pairplot(KNN, hue="TARGET CLASS")

# %% [markdown]
# Time to standardize the variables.
#
# Import StandardScaler from Scikit learn.

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Create a StandardScaler() object called scaler.

# %%
scaler = StandardScaler()

# %% [markdown]
# ** Fit scaler to the features.**

# %% [markdown]
# Use the .transform() method to transform the features to a scaled version.

# %%
data = scaler.fit_transform(KNN)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.

# %%
KNN_2 = pd.DataFrame(data,index = KNN.index, columns = KNN.columns)
KNN_2
# Out:
#          XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0    1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1   -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2    0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3    0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4   -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
# 5    1.437244 -0.827457  0.847975 -0.914267 -0.102903  1.375667 -1.137473
# 6    1.192634 -0.432092 -0.970855  1.238040  0.982445  0.728702 -0.849378
# 7    0.317560  0.446607 -1.677772 -0.347079  0.489673 -1.024006 -0.433190
# 8   -0.581391  0.249681 -1.368313  1.150715  1.703935 -0.059437 -0.266295
# 9   -0.071150 -2.014273 -0.778997 -0.462438  0.007273  0.867458 -1.517317
# 10  -0.032702 -0.422976 -1.231089  0.372275  1.700899  1.003362 -1.154517
# 11  -0.915701 -0.570926 -0.025049 -2.796507  0.986832 -0.933451  0.703997
# ...

# %% [markdown]
# Train Test Split

# %% [markdown]
# Use train_test_split to split your data into a training set and a testing set.

# %%
from sklearn.model_selection import train_test_split

# %%
X = KNN_2.as_matrix(columns=KNN_2.columns[:-1])
y = KNN_2['TARGET CLASS'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, 
                                                    random_state=101)

# %% [markdown]
# Using KNN
# - Import KNeighborsClassifier from scikit learn.
# - Create a KNN model instance with n_neighbors=1
# - Fit this KNN model to the training data.

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# Predictions and Evaluations
# **bold text**

# %% [markdown]
# Let’s evaluate our KNN model!
#
# Use the predict method to predict values using your KNN model and X_test.
# Create a confusion matrix and classification report.

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_predicted)
# Out:
# array([[152,   0],
#        [  0, 148]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00       152
#          1.0       1.00      1.00      1.00       148
#
#    micro avg       1.00      1.00      1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %% [markdown]
# Choosing a K Value

# %% [markdown]
# Let’s go ahead and use the elbow method to pick a good K Value!
#
# ** Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list. Refer to the lecture if you are confused on this step.**
#
# Now create the following plot using the information from your for loop.

# %%
error_rate = []
for i in range(1,90):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train, y_train)
  pred_i = knn.predict(X_test)
  error_rate.append( np.mean( pred_i != y_test ))

  
plt.figure(figsize=(10,6))
plt.plot(range(1,90), error_rate, marker='o')

# %% [markdown]
# Retrain with new K Value

# %% [markdown]
# Retrain your model with the best K value (up to you to decide what you want) and re-do the classification report and the confusion matrix.

# %%
K = 31
model = KNeighborsClassifier(n_neighbors=K)
model.fit(X, y)
print(confusion_matrix(y_test, y_predicted))
print(classification_report(y_test, y_predicted))
# Out:
# [[152   0]
#  [  0 148]]
#               precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00       152
#          1.0       1.00      1.00      1.00       148
#
#    micro avg       1.00      1.00      1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
